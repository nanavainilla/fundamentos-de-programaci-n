# %% [markdown]
# # ACTIVIDAD SEMANA 5

# %% [markdown]
# `Uso de tuplas`

# %% [markdown]
# 1. Crea una tupla llamada "numeros" que contenga, al menos, cinco números.
# 2. Accede al tercer elemento de la tupla e imprímelo en pantalla.
# 3. Por medio de una captura, agrega dos números adicionales a la tupla (emplea input).
# 4. Convierte la tupla en una lista y, después, ordena los elementos.
# 5. Crea una función que reciba la tupla de números como parámetro y retorne la suma de todos los elementos.
# 6. Aplica la función creada en el paso anterior a la tupla y, luego, muestra el resultado.

# %%
numeros = (8, 3, 15, 6, 10)

print("tercer numero:", numeros[2])

numero1 = int(input("ingrese un numero adicional: "))
numero2 = int(input("ingrese el segundo numero adicional: "))

numeros = numeros + (numero1, numero2)

lista = list(numeros)
lista.sort()

print("numeros ordenados:", lista)

def suma_tupla(numeros):
    return sum(numeros)

resultado = suma_tupla(numeros)

print("la suuma de todos los elementos, es:", resultado)
# Out:
# tercer numero: 15
# numeros ordenados: [2, 3, 5, 6, 8, 10, 15]
# la suuma de todos los elementos, es: 49

# %% [markdown]
# `Uso de diccionarios`

# %% [markdown]
# 1. Crea un diccionario llamado "contactos" con, al menos, tres entradas, donde las claves sean los nombres de las personas
# y los valores correspondan a sus números de teléfono.
# 2. Por medio de una captura, agrega un nuevo contacto al diccionario.
# 3. Itera sobre las claves del diccionario e imprime en pantalla los nombres de los contactos.
# 4. Crea una función que reciba el diccionario de contactos y un nombre como parámetro para que, posteriormente, retorne el
# número de teléfono correspondiente al contacto ingresado.
# 5. Aplica la función creada en el paso anterior para buscar el número de teléfono de uno de los contactos y muestra el resultado

# %%
contactos = {
    "itzel": "4421234567",
    "aldo": "4422345678",
    "sofia": "4423456789"
}

nombre = input("ingrese el nombre del nuevo contacto: ")
telefono = input("ingresa su numero de telefono: ")

contactos[nombre] = telefono

print("\ncontactos:")

for contacto in contactos:
    print(contacto)

def buscar_contacto(contactos, nombre):
    return contactos.get(nombre, "el contacto no existe")

nombre_buscar = input("\ningrese el nombre del contacto que desee buscar: ")

resultado = buscar_contacto(contactos, nombre_buscar)

print("numero de telefono:", resultado)
# Out:
# contactos:
# itzel
# aldo
# sofia
# charles
# numero de telefono: 4422345678

# %% [markdown]
# `Uso de excepciones`

# %% [markdown]
# 1. Crea un programa que solicite al usuario que ingrese dos números enteros.
# 2. Utiliza un bloque try-except para manejar la excepción que ocurrirá si el usuario ingresa un valor no numérico.
# 3. Si el usuario ingresa valores no numéricos, muestra un mensaje de error; en cambio, si los valores son numéricos,
#  muestra la suma de los dos números ingresados.
# 4. Agrega una excepción personalizada para manejar la división entre cero; por tanto, en caso de que el segundo número
# ingresado sea cero, muestra un mensaje de error adecuado

# %%
texto_num1 = input("ingrese el primer número: ")
print (texto_num1)


texto_num2 = input("ingrese el segundo número: ")
print (texto_num2)

try:
    if not texto_num1.isdigit() or not texto_num2.isdigit():
        print("ERRROR!!! debes ingresar solo números enteros.")
    
    elif texto_num2 == "0":
        print("ERROR!!! el segundo numero no puede ser cero")
        
    # Si todo está correcto, convertimos a entero y sumamos
    else:
        num1 = int(texto_num1)
        num2 = int(texto_num2)
        print("la suma de ambos numeross es:", num1 + num2)

except Exception:
    print("ocurrio un error, favor de intentarlo de nuevo!!")
# Out:
# 8
# 6
# la suma de ambos numeross es: 14

# %% [markdown]
# - muestra del mismo codigo, pero con el error

# %%
texto_num1 = input("ingrese el primer número: ")
print (texto_num1)


texto_num2 = input("ingrese el segundo número: ")
print (texto_num2)

try:
    if not texto_num1.isdigit() or not texto_num2.isdigit():
        print("ERRROR!!! debes ingresar solo números enteros.")
    
    elif texto_num2 == "0":
        print("ERROR!!! el segundo numero no puede ser cero")
        
    else:
        num1 = int(texto_num1)
        num2 = int(texto_num2)
        print("la suma de ambos numeross es:", num1 + num2)

except Exception:
    print("ocurrio un error, favor de intentarlo de nuevo!!")
# Out:
# 4
# ocho
# ERRROR!!! debes ingresar solo números enteros.

# %% [markdown]
# `Uso de strings`

# %% [markdown]
# 1. Crea una variable llamada "mensaje" que contenga un texto de tu elección.
# 2. Imprime en pantalla la longitud del mensaje.
# 3. Utiliza un método de strings para convertir todo el texto del mensaje a mayúsculas.
# 4. Utiliza otro método de strings para reemplazar una palabra específica en el mensaje por otra de tu elección.
# 5. Crea una función que reciba un string como parámetro y retorne la cantidad de palabras que contiene.
# 6. Aplica la función creada en el paso anterior al mensaje y muestra el resultado.

# %%
mensaje = "esta actividad y los ejercicios han estado muy pesados, AYUDA!!"

print("longitud del mensaje:", len(mensaje))

mensaje = mensaje.upper()
print("mensaje en mayusculas:", mensaje)

mensaje1 = mensaje.replace("AYUDA", "me encanta!")
print("mensaje modificado:", mensaje1) 

def contar_palabras(texto):
    return len(texto.split())

cantidad = contar_palabras(mensaje)
print("cantidad de palabras:", cantidad)
# Out:
# longitud del mensaje: 63
# mensaje en mayusculas: ESTA ACTIVIDAD Y LOS EJERCICIOS HAN ESTADO MUY PESADOS, AYUDA!!
# mensaje modificado: ESTA ACTIVIDAD Y LOS EJERCICIOS HAN ESTADO MUY PESADOS, me encanta!!!
# cantidad de palabras: 10

# %% [markdown]
# `Menú principal`

# %% [markdown]
# 1. Crea un menú principal que permita elegir qué tipo de dato se desea capturar.
# 2. De acuerdo con la elección hecha por el usuario, llama a la función indicada para proceder a su ejecución.
# 3. Agrega una opción para finalizar la ejecución

# %%
def capturar_desayuno():
    print("hot cakes & huevito!!")

def capturar_comida():
    print("7 mojarras, sopa de fideo y 3 sopes!!")

def capturar_cena():
    print("zucaritas con platano!!")

# menuuu
opcion = ()
while opcion != "4":
    print("\nMENUUUU")
    print("1. opcion del dia del desayuno")
    print("2. opcion del dia de la comida")
    print("3. opcion del dia de la cena")
    print("4. no tengo hambre!")

    opcion = input("ingrese la opcion que desee comprar: ")

    if opcion in ["1", "2", "3"]:
            if opcion == "1":
                capturar_desayuno()
            elif opcion == "2":
                capturar_comida()
            elif opcion == "3":
                capturar_cena()
            pregunta = input("esta seguro que quiere comprar la comida?: ").strip().lower()
            if pregunta == "si":
                print("perrrrfectooo!! paga!!")
            else:
             print("entonces vete al Vips, nacooooo!")

    elif opcion == "4":
        print("el programa ha ssido finalizadooo!!!")
    else:
        print("esa opcion no se valeee!! intente de nuevo!!")
# Out:
# MENUUUU
# 1. opcion del dia del desayuno
# 2. opcion del dia de la comida
# 3. opcion del dia de la cena
# 4. no tengo hambre!
# zucaritas con platano!!
# entonces vete al Vips, nacooooo!
#
# MENUUUU
# 1. opcion del dia del desayuno
# 2. opcion del dia de la comida
# 3. opcion del dia de la cena
# 4. no tengo hambre!
# 7 mojarras, sopa de fideo y 3 sopes!!
# perrrrfectooo!! paga!!
#
# MENUUUU
# 1. opcion del dia del desayuno
# 2. opcion del dia de la comida
# 3. opcion del dia de la cena
# 4. no tengo hambre!
# el programa ha ssido finalizadooo!!!
